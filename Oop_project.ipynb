# %% [markdown]
# <a href="https://colab.research.google.com/github/rishugupta9621/DSMP/blob/main/Oop_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nlpcloud
# https://nlpcloud.com/home/playground/language-detection
# Out:
# Requirement already satisfied: nlpcloud in /usr/local/lib/python3.12/dist-packages (1.1.47)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from nlpcloud) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (2026.5.20)

# %%
import nlpcloud

client = nlpcloud.Client("finetuned-gpt-neox-20b", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=True, lang="en")
client.entities("""John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""", searched_entity="programming languages")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/nlpcloud/__init__.py in entities(self, text, searched_entity)
#     184         try:
# --> 185             r.raise_for_status()
#     186         except HTTPError as err:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_14478/393128055.py in <cell line: 0>()
#       2
#       3 client = nlpcloud.Client("finetuned-gpt-neox-20b", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=True, lang="en")
# ----> 4 client.entities("""John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""", searched_entity="programming languages")
#
# /usr/local/lib/python3.12/dist-packages/nlpcloud/__init__.py in entities(self, text, searched_entity)
#     188                 raise HTTPError(str(err))
#     189
# --> 190             raise HTTPError(str(err) + ": " + str(r.text))
#     191
#     192         return r.json()
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities: Rate limit: maximum number of requests per hour reached. Please contact support to learn how to increase this limit (if you are on the free plan, we encourage you to subscribe to the pay-as-you-go plan which provides a much higher throughput and many free requests). You can change your plan here: https://nlpcloud.com/home/plans.

# %%
import nlpcloud

client = nlpcloud.Client("distilbert-base-uncased-emotion", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=False, lang="en")
client.sentiment("Look what's just come on the market in #ValThorens! A recently renovated, charming 6 bed duplex apartment in the heart of the resort with superb views!")
# Out:
# {'scored_labels': [{'label': 'sadness', 'score': 0.0001777907891664654},
#   {'label': 'joy', 'score': 0.9987751841545105},
#   {'label': 'love', 'score': 0.0004087708657607436},
#   {'label': 'anger', 'score': 0.00012217740004416555},
#   {'label': 'fear', 'score': 0.00011809932038886473},
#   {'label': 'surprise', 'score': 0.0003979843750130385}]}

# %%
import nlpcloud

client = nlpcloud.Client("distilbert-base-uncased-emotion", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=False, lang="en")
client.sentiment("Look what's just come on the market in #ValThorens! A recently renovated, charming 6 bed duplex apartment in the heart of the resort with superb views!")
# Out:
# {'scored_labels': [{'label': 'sadness', 'score': 0.0001777907891664654},
#   {'label': 'joy', 'score': 0.9987751841545105},
#   {'label': 'love', 'score': 0.00040877042920328677},
#   {'label': 'anger', 'score': 0.00012217740004416555},
#   {'label': 'fear', 'score': 0.00011809932038886473},
#   {'label': 'surprise', 'score': 0.0003979839675594121}]}

# %%
import nlpcloud

client = nlpcloud.Client("python-langdetect", "3126efa8746a8c9a683e757205437143fa015ec5")
client.langdetection("""Et il parle aussi un peu français.""")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/nlpcloud/__init__.py in langdetection(self, text)
#     294         try:
# --> 295             r.raise_for_status()
#     296         except HTTPError as err:
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.nlpcloud.io/v1/python-langdetect/langdetection
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-5f794e4058ed> in <module>
#       2
#       3 client = nlpcloud.Client("python-langdetect", "3126efa8746a8c9a683e757205437143fa015ec5")
# ----> 4 client.langdetection("""Et il parle aussi un peu français.""")
#
# /usr/local/lib/python3.7/dist-packages/nlpcloud/__init__.py in langdetection(self, text)
#     298                 raise HTTPError(str(err))
#     299
# --> 300             raise HTTPError(str(err) + ": " + str(r.text))
#     301
#     302         return r.json()
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.nlpcloud.io/v1/python-langdetect/langdetection:

# %%
import nlpcloud

client = nlpcloud.Client("finetuned-gpt-neox-20b", "3126efa8746a8c9a683e757205437143fa015ec5", gpu=True, lang="en")
client.entities("""John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""", searched_entity="programming languages")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/nlpcloud/__init__.py in entities(self, text, searched_entity)
#     178         try:
# --> 179             r.raise_for_status()
#     180         except HTTPError as err:
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-a53eea815cda> in <module>
#       2
#       3 client = nlpcloud.Client("finetuned-gpt-neox-20b", "3126efa8746a8c9a683e757205437143fa015ec5", gpu=True, lang="en")
# ----> 4 client.entities("""John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""", searched_entity="programming languages")
#
# /usr/local/lib/python3.7/dist-packages/nlpcloud/__init__.py in entities(self, text, searched_entity)
#     182                 raise HTTPError(str(err))
#     183
# --> 184             raise HTTPError(str(err) + ": " + str(r.text))
#     185
#     186         return r.json()
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities:

# %%
# !pip install nlpcloud
# Out:
# Requirement already satisfied: nlpcloud in /usr/local/lib/python3.12/dist-packages (1.1.47)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from nlpcloud) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (2026.5.20)

# %%
import nlpcloud
class NLPApp:

 def __init__(self):
    self.__database={}
    # Replace 'YOUR_NLPCLOUD_API_KEY' with your actual NLP Cloud API key
    self.nlpcloud_api_key = "YOUR_NLPCLOUD_API_KEY"
    self.__first_menu()


 def __first_menu(self):
  first_input=input("""
  Hi!! How Woluld Like To Proceed ?
  1.Register
  2.Login
  3.Exit
  """)
  if first_input=="1":
     self.__register()
  elif first_input=="2":
     self.__login()
  else:
    exit()



 def __second_menu(self):
      second_input=input("""
  Hi!! How Woluld Like To Proceed ?
  1.NER
  2.Language Detection
  3.Sentiment Analysis
  4.Logout
  """)

      if second_input=="1":
        self.__ner()
      elif second_input=="2":
        self.__language_detection()
      elif second_input=="3":
        self.__sentiment_analysis()
      else:
        exit()





 def __register(self):
    name=input("Enter Name::")
    email=input("Enter Email::")
    password=input("Enter Password::")

    if email in self.__database:
      print("This Email Has Already Exits")
    else:
      self.__database[email]=[name,password]
      print("your registeration have successfully".title())
      print(self.__database)
      self.__first_menu()

 def __login(self):
    email=input("Enter Email::")
    password=input("Enter Password::")

    if email in self.__database:
      if self.__database[email][1]== password:
        print("You are Login Successfully!!")
        self.__second_menu()

    else:
      print("This Email has not register!!")
      self.__first_menu()



 def __ner(self):
      para=input("Enter The Paragraph::")
      search=input("What Would You Like To Search?::")

      client = nlpcloud.Client("finetuned-gpt-neox-20b", self.nlpcloud_api_key, gpu=True, lang="en")
      response=client.entities(para, searched_entity=search)
      print(response)
      self.__second_menu()

 def __language_detection(self):
    para = input("Enter The Paragraph::")

    client = nlpcloud.Client("python-langdetect", self.nlpcloud_api_key)
    response = client.langdetection(para)
    print(response)
    self.__second_menu()



 def __sentiment_analysis(self):
    para = input("Enter The Paragraph::")

    client = nlpcloud.Client("distilbert-base-uncased-emotion", self.nlpcloud_api_key, gpu=False, lang="en")
    response = client.sentiment(para)

    L=[]

    for i in response['scored_labels']:
      L.append(i['score'])

    index= sorted(list(enumerate(L)),key=lambda x:x[1],reverse = True) [0][0]
    print(response['scored_labels'][index]['label'])
    self.__second_menu()

# %%
obj=NLPApp()
# Out:
#   Hi!! How Woluld Like To Proceed ?
#   1.Register
#   2.Login
#   3.Exit
#   1
# Enter Name::rishu
# Enter Email::rishu@gmail.com
# Enter Password::1234
# Your Registeration Have Successfully
# {'rishu@gmail.com': ['rishu', '1234']}
#
#   Hi!! How Woluld Like To Proceed ?
#   1.Register
#   2.Login
#   3.Exit
#   2
# Enter Email::rishu@gmail.com
# Enter Password::1234
# You are Login Successfully!!
#
#   Hi!! How Woluld Like To Proceed ?
#   1.NER
#   2.Language Detection
#   3.Sentiment Analysis
#   4.Logout
#   3
# Enter The Paragraph::Look what's just come on the market in #ValThorens! A recently renovated, charming 6 bed duplex apartment in the heart of the resort with superb views!
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/nlpcloud/__init__.py in sentiment(self, text, target)
#     407         try:
# --> 408             r.raise_for_status()
#     409         except HTTPError as err:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.nlpcloud.io/v1/distilbert-base-uncased-emotion/sentiment
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_82706/2664406750.py in <cell line: 0>()
# ----> 1 obj=NLPApp()
#
# /tmp/ipykernel_82706/1362670516.py in __init__(self)
#       6     # Replace 'YOUR_NLPCLOUD_API_KEY' with your actual NLP Cloud API key
#       7     self.nlpcloud_api_key = "YOUR_NLPCLOUD_API_KEY"
# ----> 8     self.__first_menu()
#       9
#      10
#
# /tmp/ipykernel_82706/1362670516.py in __first_menu(self)
#      17   """)
#      18   if first_input=="1":
# ---> 19      self.__register()
#      20   elif first_input=="2":
#      21      self.__login()
#
# /tmp/ipykernel_82706/1362670516.py in __register(self)
#      58       print("your registeration have successfully".title())
#      59       print(self.__database)
# ---> 60       self.__first_menu()
#      61
#      62  def __login(self):
#
# /tmp/ipykernel_82706/1362670516.py in __first_menu(self)
#      19      self.__register()
#      20   elif first_input=="2":
# ---> 21      self.__login()
#      22   else:
#      23     exit()
#
# /tmp/ipykernel_82706/1362670516.py in __login(self)
#      67       if self.__database[email][1]== password:
#      68         print("You are Login Successfully!!")
# ---> 69         self.__second_menu()
#      70
#      71     else:
#
# /tmp/ipykernel_82706/1362670516.py in __second_menu(self)
#      39         self.__language_detection()
#      40       elif second_input=="3":
# ---> 41         self.__sentiment_analysis()
#      42       else:
#      43         exit()
#
# /tmp/ipykernel_82706/1362670516.py in __sentiment_analysis(self)
#      98
#      99     client = nlpcloud.Client("distilbert-base-uncased-emotion", self.nlpcloud_api_key, gpu=False, lang="en")
# --> 100     response = client.sentiment(para)
#     101
#     102     L=[]
#
# /usr/local/lib/python3.12/dist-packages/nlpcloud/__init__.py in sentiment(self, text, target)
#     408             r.raise_for_status()
#     409         except HTTPError as err:
# --> 410             raise HTTPError(str(err) + ": " + str(r.text))
#     411
#     412         return r.json()
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.nlpcloud.io/v1/distilbert-base-uncased-emotion/sentiment:

# %%
d={'scored_labels': [{'label': 'sadness', 'score': 0.0001777907891664654},
  {'label': 'joy', 'score': 0.9987751841545105},
  {'label': 'love', 'score': 0.00040877042920328677},
  {'label': 'anger', 'score': 0.00012217740004416555},
  {'label': 'fear', 'score': 0.00011809932038886473},
  {'label': 'surprise', 'score': 0.0003979839675594121}]}

# %%
L=[]

for i in d['scored_labels']:
  L.append(i['score'])

index= sorted(list(enumerate(L)) , key=lambda x:x[1],reverse = True) [0][0]
d['scored_labels'][index]['label']
# Out:
# 'joy'

# %%
L = []
for i in d['scored_labels']:
  L.append(i['score'])

index = sorted(list(enumerate(L)),key=lambda x:x[1],reverse=True)[0][0]

# %%
d['scored_labels'][index]['label']
# Out:
# 'sadness'

# %%
import emoji
print(emoji.emojize('Python is :grinning_face:'))
# Out:
# Python is 😀

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      |████████████████████████████████| 240 kB 15.2 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234926 sha256=41b6c4bb33328577a544347fe1c0258b19e2bac46989d0bb233c97ed1d66de05
#   Stored in directory: /root/.cache/pip/wheels/f3/e3/f2/1de1c2e3ed742e1df73e0f15d58864e50c7e64f607b548d6cf
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.2.0
