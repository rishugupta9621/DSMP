# %% [markdown]
# <a href="https://colab.research.google.com/github/rishugupta9621/DSMP/blob/main/Copy_of_session_7_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L=[1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_539/622841889.py in <cell line: 0>()
#       1 L=[1,2,3]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
s.append('x')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_539/666329863.py in <cell line: 0>()
#       1 s = 'hello'
# ----> 2 s.append('x')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
s = [1,2,3]

# %%
# syntax to create an object

#objectname = classname()

# %%
# object literal
L = [1,2,3]

# %%
L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %%
# Pascal Case

HelloWorld

# %%
class Atm: ## I am focus on logic
  #constructor ---->superpower
  def __init__(self):
    self.pin=''
    self.balance = 0
    self.menu()


  def menu(self):
    user_input=input("""
    How Can I Help You?
    1.press 1 to create pin
    2.press 2 to change pin
    3.press 3 to check balance
    4.press 4 to withdraw balance
    5.press 5 to exit
    """)

    if user_input=='1':
       self.create_pin()
    elif user_input=='2':
      self.change_pin()
    elif user_input=='3':
      self.check_balance()
    elif user_input=='4':
      self.Withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin=int(input("Enter Your Pin To SetUp ::"))
    self.pin=user_pin
    user_bal=int(input("Enter Your Balance Amount:"))
    self.balance=user_bal
    print(f"Pin has Created Successfully!! And Your Balance Amount is {self.balance}")
    self.menu()

  def change_pin(self):
    user_pinchange=int(input("Enter Your Old Pin::"))
    if user_pinchange==self.pin:
      user_newpin=int(input("Enter New Pin::"))

    else:
      print("Try Again later")
      self.menu()
    print(f"New Pin Created Successfully And Remaining Balance is {self.balance}")


  def check_balance(self):
      check_pin=int(input("Enter Your Pin::"))
      if check_pin==self.pin:
        print(f"Your Remaining Balance is {self.balance}")
        self.menu()
      else:
        print('Try Again Later')
        self.menu()


  def Withdraw(self):
    check_pin=int(input("Enter Your Pin ::"))
    if check_pin==self.pin:
      user_amo = int(input('Enter Withdraw Amount:'))
      if user_amo<self.balance:
        new_amount=self.balance-user_amo
        print(f"Remaining Balance Amount is {new_amount}")
        self.menu()
      else:
        print(f"Your Balance Amount Is Low!!")
        self.menu()
    else:
      print("Try Again Later")
      self.menu()

# %%
obj1 = Atm()
# Out:
#     How Can I Help You?
#     1.press 1 to create pin
#     2.press 2 to change pin
#     3.press 3 to check balance
#     4.press 4 to withdraw balance
#     5.press 5 to exit
#     1
# Enter Your Pin To SetUp ::1234
# Enter Your Balance Amount:2000
# Pin has Created Successfully!! And Your Balance Amount is 2000
#
#     How Can I Help You?
#     1.press 1 to create pin
#     2.press 2 to change pin
#     3.press 3 to check balance
#     4.press 4 to withdraw balance
#     5.press 5 to exit
#     4
# Enter Your Pin ::1234
# Enter Withdraw Amount:12
# Remaining Balance Amount is 1988

# %%
id(obj1)
# Out:
# 139115834434496

# %%
obj2 = Atm()
# Out:
# 140289660586384

# %%
id(obj2)
# Out:
# 140289660586384

# %%
L = [1,2,3]
len(L) # function ->bcos it is outside the list class
L.append()# method -> bcos it is inside the list class

# %%
class Temp:

  def __init__(self):
    print('hello')

obj = Temp()
# Out:
# hello

# %%
3/4*1/2
# Out:
# 0.375

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return Fraction(new_num,new_den)

  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return Fraction(new_num,new_den)

  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den

    return Fraction(new_num,new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return Fraction(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
fr1.convert_to_decimal()
# 3/4
# Out:
# 0.75

# %%
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %%
s1={1,2,3}
s2={3,4,5}

s1 + s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3a417afc75fb> in <module>
#       2 s2={3,4,5}
#       3
# ----> 4 s1 + s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
print(fr1 - fr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-929bcd8b32dc> in <module>
# ----> 1 print(fr1 - fr2)
#
# TypeError: unsupported operand type(s) for -: 'Fraction' and 'Fraction'
